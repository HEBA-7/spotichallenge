# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# imports
import requests
import pandas as pd
import re
import json
import math

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# generate token with a POST request

client_id = "52bada9e1a9d407498596746d5b8fbdd"
client_secret = "540e0148e2e0431c9f983f2257e5c6ac"
auth_url = 'https://accounts.spotify.com/api/token'

# %%
auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
access_token = auth_response['access_token']
auth_response
# Out:
# {'access_token': 'BQAcRRieyqZlV5I5FDysya3GaCq9JM_ONRJAzlkZkNu_p6x_p7febQnER3tPVjB-mYGABe9tFGxOuImUHSPfFJdSe6LgzKZNKOq6vrwRn3DDhFA8lDU',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_url` (i.e.: End-point), parameters and `headers` for your __GET__ operations

# %%
# setting the main variables
base_url = 'https://api.spotify.com/v1'
resource = '/artists'
parameters = '/711MCceyCBcFnzjGY4Q7Un'
market = '?market=ES'
header = {'Authorization': 'Bearer {token}'.format(token=access_token)}
header
# Out:
# {'Authorization': 'Bearer BQAcRRieyqZlV5I5FDysya3GaCq9JM_ONRJAzlkZkNu_p6x_p7febQnER3tPVjB-mYGABe9tFGxOuImUHSPfFJdSe6LgzKZNKOq6vrwRn3DDhFA8lDU'}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need
#
# __Here you have the different artists to start with:__
#
# _Option 1:_ 711MCceyCBcFnzjGY4Q7Un
#
# _Option 2:_ 5gs3QMiBgkUgNofeA16Awv
#
# _Option 3:_ 1ZcvF2meiXi5UPDJWxrKR5
#
# _Option 4:_ 0HSGpDMeXaEmH5aUIHjnBF
#
# _Option 5:_ 5TYxZTjIPqKM8K8NuP9woO
#
# _Option 6:_ 36QJpDe2go2KgaRleHCDTp
#
# _Option 7:_ 3qm84nBOXUEQ2vnTfUTTFC
#
# _Option 8:_ 4NJhFmfw43RLBLjQvxDuRS
#
# _Option 9:_ 0L8ExT028jH3ddEcZwqJJ5
#
# _Option 10:_ 1vCWHaC5f2uS3yhpwWbIA6
#
# _Option 11:_ 1dfeR4HaWDbWqFHLkxsg1d
#
# _Option 12:_ 6ogn9necmbUdCppmNnGOdi

# %%
base_url = 'https://api.spotify.com/v1'
resource = '/artists'
parameters = '/711MCceyCBcFnzjGY4Q7Un/'
header = {'Authorization': 'Bearer {token}'.format(token=access_token)}
header
artist = requests.get(base_url + resource + parameters, headers = header).json()
type(artist)
artist.keys()
# Out:
# dict_keys(['external_urls', 'followers', 'genres', 'href', 'id', 'images', 'name', 'popularity', 'type', 'uri'])

# %%
print(artist["name"] + " " + "the id is:" + " " + artist["id"])
# Out:
# AC/DC the id is: 711MCceyCBcFnzjGY4Q7Un

# %%
# related artists for AC/DC
resource = '/artists'
parameters = '/711MCceyCBcFnzjGY4Q7Un/related-artists'
related_artists = requests.get(base_url + resource + parameters, headers = header).json()
type(related_artists['artists'])
related_artists['artists'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#  'followers': {'href': None, 'total': 24938860},
#  'genres': ['glam metal', 'hard rock', 'rock'],
#  'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#  'id': '3qm84nBOXUEQ2vnTfUTTFC',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb50defaf9fc059a1efc541f4c',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab6761610000517450defaf9fc059a1efc541f4c',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f17850defaf9fc059a1efc541f4c',
#    'width': 160}],
#  'name': "Guns N' Roses",
#  'popularity': 78,
#  'type': 'artist',
#  'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}

# %%
df_related_artists = pd.DataFrame(related_artists['artists'], columns = ["name", "id"])
df_related_artists
# Out:
#               name                      id
# 0    Guns N' Roses  3qm84nBOXUEQ2vnTfUTTFC
# 1        Airbourne  6urzdpGY5yUimWZsgJUoTb
# 2             KISS  07XSN3sPlIlB2L2XNcTwJw
# 3        Aerosmith  7Ey4PD4MYsKc5I2dolUwbH
# 4     Alice Cooper  3EhbVgyfGd7HkpsagwL9GS
# 5     Judas Priest  2tRsMl4eGxwoNabM08Dm4I
# 6              Dio  4CYeVo5iZbtYGBN4Isc3n6
# 7    Ozzy Osbourne  6ZLTlhejhndI4Rh53vYhrY
# 8        Scorpions  27T030eWyCQRmDyuvr1kxY
# 9      Deep Purple  568ZhdwyaiCyOGJRtNYhWf
# 10     Iron Maiden  6mdiAmATAx73kdxrNrnlao
# 11   Black Sabbath  5M52tdBnJaKSvOpJGz8mfZ
# 12  Twisted Sister  7b85ve82Sh36a3UAx74wut
# 13     Mötley Crüe  0cc6vw3VN8YlIcvr1v7tBL
# 14       Motörhead  1DFr97A9HnbV3SKTJFu62M
# 15      Quiet Riot  1dLWg6m8RRhizsdqJbhyj3
# 16          ZZ Top  2AM4ilv6UzW0uMRuqKtDgN
# 17        The Cult  49DW3KvkyjHO35mK1JnSyS
# 18       Van Halen  2cnMpRsOVqtPMfq7YiFE6K
# 19         Rainbow  6SLAMfhOi7UJI0fMztaK0m

# %%
id_df_related_artists =  pd.DataFrame(related_artists['artists'], columns = ["id"])
print(type(id_df_related_artists))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#convierto en lista los ids
id_related_artists = []
for i in related_artists['artists']:
    id_related_artists.append(i['id'])
id_related_artists
# Out:
# ['3qm84nBOXUEQ2vnTfUTTFC',
#  '6urzdpGY5yUimWZsgJUoTb',
#  '07XSN3sPlIlB2L2XNcTwJw',
#  '7Ey4PD4MYsKc5I2dolUwbH',
#  '3EhbVgyfGd7HkpsagwL9GS',
#  '2tRsMl4eGxwoNabM08Dm4I',
#  '4CYeVo5iZbtYGBN4Isc3n6',
#  '6ZLTlhejhndI4Rh53vYhrY',
#  '27T030eWyCQRmDyuvr1kxY',
#  '568ZhdwyaiCyOGJRtNYhWf',
#  '6mdiAmATAx73kdxrNrnlao',
#  '5M52tdBnJaKSvOpJGz8mfZ',
#  '7b85ve82Sh36a3UAx74wut',
#  '0cc6vw3VN8YlIcvr1v7tBL',
#  '1DFr97A9HnbV3SKTJFu62M',
#  '1dLWg6m8RRhizsdqJbhyj3',
#  '2AM4ilv6UzW0uMRuqKtDgN',
#  '49DW3KvkyjHO35mK1JnSyS',
#  '2cnMpRsOVqtPMfq7YiFE6K',
#  '6SLAMfhOi7UJI0fMztaK0m']

# %%
# now the top-tracks
base_url = 'https://api.spotify.com/v1'
id_relart = '6urzdpGY5yUimWZsgJUoTb'
url_id_top = base_url + resource + '/'+ id_relart + "/top-tracks" + market
url_id_top
# Out:
# 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb/top-tracks?market=ES'

# %%
top_tracks = requests.get(url_id_top, headers = header).json()
print(type(top_tracks))
top_tracks
# Out:
# <class 'dict'>
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#       'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#       'id': '6urzdpGY5yUimWZsgJUoTb',
#       'name': 'Airbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0xsxAYE1bJEvQYYZRdotdO'},
#     'href': 'https://api.spotify.com/v1/albums/0xsxAYE1bJEvQYYZRdotdO',
#     'id': '0xsxAYE1bJEvQYYZRdotdO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f14b478eb49241dd646c8626',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f14b478eb49241dd646c8626',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f14b478eb49241dd646c8626',
#       'width': 64}],
#     'name': "Runnin' Wild (Special Edition)",
#     'release_date': '2007',
#     'release_date_precision': 'year',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:0xsxAYE1bJEvQYYZRdotdO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#      'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#      'id': '6urzdpGY5yUimWZsgJUoTb',
#      'name': 'Airbourne',
#      'type': 'artist',
#      'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#    'disc_number': 1,
#    'duration_ms': 222240,
#    'explicit': False,
#    'external_ids': {'isrc': 'NLA320786218'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/71fSn6OIF7HnCbgCzOBqpj'},
#    'href': 'https://api.spotify.com/v1/tracks/71fSn6OIF7HnCbgCzOBqpj',
#    'id': '71fSn6OIF7HnCbgCzOBqpj',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Runnin' Wild",
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1ca2400fde80253e339d6cefbb9fe7647307a9a5?cid=52bada9e1a9d407498596746d5b8fbdd',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:71fSn6OIF7HnCbgCzOBqpj'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#       'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#       'id': '6urzdpGY5yUimWZsgJUoTb',
#       'name': 'Airbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0xsxAYE1bJEvQYYZRdotdO'},
#     'href': 'https://api.spotify.com/v1/albums/0xsxAYE1bJEvQYYZRdotdO',
#     'id': '0xsxAYE1bJEvQYYZRdotdO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f14b478eb49241dd646c8626',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f14b478eb49241dd646c8626',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f14b478eb49241dd646c8626',
#       'width': 64}],
#     'name': "Runnin' Wild (Special Edition)",
#     'release_date': '2007',
#     'release_date_precision': 'year',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:0xsxAYE1bJEvQYYZRdotdO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#      'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#      'id': '6urzdpGY5yUimWZsgJUoTb',
#      'name': 'Airbourne',
#      'type': 'artist',
#      'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#    'disc_number': 1,
#    'duration_ms': 226706,
#    'explicit': False,
#    'external_ids': {'isrc': 'NLA320786227'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2LQbBzrXkgQHnCDUmHjReH'},
#    'href': 'https://api.spotify.com/v1/tracks/2LQbBzrXkgQHnCDUmHjReH',
#    'id': '2LQbBzrXkgQHnCDUmHjReH',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Too Much, Too Young, Too Fast',
#    'popularity': 62,
#    'preview_url': 'https://p.scdn.co/mp3-preview/76a6d586dccca2e7f8624b30c62589edbd8f1306?cid=52bada9e1a9d407498596746d5b8fbdd',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:2LQbBzrXkgQHnCDUmHjReH'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#       'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#       'id': '6urzdpGY5yUimWZsgJUoTb',
#       'name': 'Airbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2rtA2D8SqJ1aGUd3flJYFP'},
#     'href': 'https://api.spotify.com/v1/albums/2rtA2D8SqJ1aGUd3flJYFP',
#     'id': '2rtA2D8SqJ1aGUd3flJYFP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bdcbcbeb6eb780a6340d71a4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bdcbcbeb6eb780a6340d71a4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bdcbcbeb6eb780a6340d71a4',
#       'width': 64}],
#     'name': "Breakin' Outta Hell",
#     'release_date': '2016-09-23',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:2rtA2D8SqJ1aGUd3flJYFP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#      'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#      'id': '6urzdpGY5yUimWZsgJUoTb',
#      'name': 'Airbourne',
#      'type': 'artist',
#      'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#    'disc_number': 1,
#    'duration_ms': 232425,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBUM71603460'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3HFqO1Khvk1pdmhjz3tXsk'},
#    'href': 'https://api.spotify.com/v1/tracks/3HFqO1Khvk1pdmhjz3tXsk',
#    'id': '3HFqO1Khvk1pdmhjz3tXsk',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Breakin' Outta Hell",
#    'popularity': 62,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3HFqO1Khvk1pdmhjz3tXsk'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#       'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#       'id': '6urzdpGY5yUimWZsgJUoTb',
#       'name': 'Airbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2ByV33s2Y1uJRAooa8ivrn'},
#     'href': 'https://api.spotify.com/v1/albums/2ByV33s2Y1uJRAooa8ivrn',
#     'id': '2ByV33s2Y1uJRAooa8ivrn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d2b045e3984afcb82cdc9a83',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d2b045e3984afcb82cdc9a83',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d2b045e3984afcb82cdc9a83',
#       'width': 64}],
#     'name': 'Black Dog Barking (Special Edition)',
#     'release_date': '2013-05-17',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:2ByV33s2Y1uJRAooa8ivrn'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#      'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#      'id': '6urzdpGY5yUimWZsgJUoTb',
#      'name': 'Airbourne',
#      'type': 'artist',
#      'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#    'disc_number': 1,
#    'duration_ms': 205506,
#    'explicit': False,
#    'external_ids': {'isrc': 'NLA321392615'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2XjeZEdPK7Qo66Z7ONp854'},
#    'href': 'https://api.spotify.com/v1/tracks/2XjeZEdPK7Qo66Z7ONp854',
#    'id': '2XjeZEdPK7Qo66Z7ONp854',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Back In the Game',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8b0f37e76c0857caf8e2b6081757503832ea936b?cid=52bada9e1a9d407498596746d5b8fbdd',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:2XjeZEdPK7Qo66Z7ONp854'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#       'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#       'id': '6urzdpGY5yUimWZsgJUoTb',
#       'name': 'Airbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6AbeBnRjJOIQNojzrU4NMA'},
#     'href': 'https://api.spotify.com/v1/albums/6AbeBnRjJOIQNojzrU4NMA',
#     'id': '6AbeBnRjJOIQNojzrU4NMA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734ffd3562eed9c658e31029c7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024ffd3562eed9c658e31029c7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514ffd3562eed9c658e31029c7',
#       'width': 64}],
#     'name': 'Black Dog Barking',
#     'release_date': '2013-05-17',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:6AbeBnRjJOIQNojzrU4NMA'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#      'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#      'id': '6urzdpGY5yUimWZsgJUoTb',
#      'name': 'Airbourne',
#      'type': 'artist',
#      'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#    'disc_number': 1,
#    'duration_ms': 265086,
#    'explicit': False,
#    'external_ids': {'isrc': 'NLA321392617'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0sa1kd1ZDMHopmdY66GcOQ'},
#    'href': 'https://api.spotify.com/v1/tracks/0sa1kd1ZDMHopmdY66GcOQ',
#    'id': '0sa1kd1ZDMHopmdY66GcOQ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Live It Up',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/72c6cedb042dcac16f862ee81e450392704f34bc?cid=52bada9e1a9d407498596746d5b8fbdd',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:0sa1kd1ZDMHopmdY66GcOQ'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#       'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#       'id': '6urzdpGY5yUimWZsgJUoTb',
#       'name': 'Airbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2rtA2D8SqJ1aGUd3flJYFP'},
#     'href': 'https://api.spotify.com/v1/albums/2rtA2D8SqJ1aGUd3flJYFP',
#     'id': '2rtA2D8SqJ1aGUd3flJYFP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bdcbcbeb6eb780a6340d71a4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bdcbcbeb6eb780a6340d71a4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bdcbcbeb6eb780a6340d71a4',
#       'width': 64}],
#     'name': "Breakin' Outta Hell",
#     'release_date': '2016-09-23',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:2rtA2D8SqJ1aGUd3flJYFP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#      'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#      'id': '6urzdpGY5yUimWZsgJUoTb',
#      'name': 'Airbourne',
#      'type': 'artist',
#      'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#    'disc_number': 1,
#    'duration_ms': 212190,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71603856'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6seQdTp9Vi0BE3z4DdJSAE'},
#    'href': 'https://api.spotify.com/v1/tracks/6seQdTp9Vi0BE3z4DdJSAE',
#    'id': '6seQdTp9Vi0BE3z4DdJSAE',
#    'is_local': False,
#    'is_playable': True,
#    'name': "It's All For Rock N' Roll",
#    'popularity': 53,
#    'preview_url': None,
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:6seQdTp9Vi0BE3z4DdJSAE'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#       'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#       'id': '6urzdpGY5yUimWZsgJUoTb',
#       'name': 'Airbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0xsxAYE1bJEvQYYZRdotdO'},
#     'href': 'https://api.spotify.com/v1/albums/0xsxAYE1bJEvQYYZRdotdO',
#     'id': '0xsxAYE1bJEvQYYZRdotdO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f14b478eb49241dd646c8626',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f14b478eb49241dd646c8626',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f14b478eb49241dd646c8626',
#       'width': 64}],
#     'name': "Runnin' Wild (Special Edition)",
#     'release_date': '2007',
#     'release_date_precision': 'year',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:0xsxAYE1bJEvQYYZRdotdO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#      'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#      'id': '6urzdpGY5yUimWZsgJUoTb',
#      'name': 'Airbourne',
#      'type': 'artist',
#      'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#    'disc_number': 1,
#    'duration_ms': 240133,
#    'explicit': False,
#    'external_ids': {'isrc': 'NLA320786224'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1R8T9Hnsz0M01pheJIi5qT'},
#    'href': 'https://api.spotify.com/v1/tracks/1R8T9Hnsz0M01pheJIi5qT',
#    'id': '1R8T9Hnsz0M01pheJIi5qT',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Heartbreaker',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8c320d719b7e5abb76f325bb45cfeff87c2cd43c?cid=52bada9e1a9d407498596746d5b8fbdd',
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:1R8T9Hnsz0M01pheJIi5qT'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#       'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#       'id': '6urzdpGY5yUimWZsgJUoTb',
#       'name': 'Airbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3exqV2MhKWetLhgfc7RPBO'},
#     'href': 'https://api.spotify.com/v1/albums/3exqV2MhKWetLhgfc7RPBO',
#     'id': '3exqV2MhKWetLhgfc7RPBO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730b08421d532524e82068010f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020b08421d532524e82068010f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510b08421d532524e82068010f',
#       'width': 64}],
#     'name': 'Boneshaker',
#     'release_date': '2019-10-25',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:3exqV2MhKWetLhgfc7RPBO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#      'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#      'id': '6urzdpGY5yUimWZsgJUoTb',
#      'name': 'Airbourne',
#      'type': 'artist',
#      'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#    'disc_number': 1,
#    'duration_ms': 203137,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71903533'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4Uj8nBnk0tKpu2qIeLqUvZ'},
#    'href': 'https://api.spotify.com/v1/tracks/4Uj8nBnk0tKpu2qIeLqUvZ',
#    'id': '4Uj8nBnk0tKpu2qIeLqUvZ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Backseat Boogie',
#    'popularity': 51,
#    'preview_url': None,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:4Uj8nBnk0tKpu2qIeLqUvZ'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#       'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#       'id': '6urzdpGY5yUimWZsgJUoTb',
#       'name': 'Airbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2rtA2D8SqJ1aGUd3flJYFP'},
#     'href': 'https://api.spotify.com/v1/albums/2rtA2D8SqJ1aGUd3flJYFP',
#     'id': '2rtA2D8SqJ1aGUd3flJYFP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bdcbcbeb6eb780a6340d71a4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bdcbcbeb6eb780a6340d71a4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bdcbcbeb6eb780a6340d71a4',
#       'width': 64}],
#     'name': "Breakin' Outta Hell",
#     'release_date': '2016-09-23',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:2rtA2D8SqJ1aGUd3flJYFP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#      'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#      'id': '6urzdpGY5yUimWZsgJUoTb',
#      'name': 'Airbourne',
#      'type': 'artist',
#      'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#    'disc_number': 1,
#    'duration_ms': 243385,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71603858'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/71NvO4cZEmDcVg0s1ryrfg'},
#    'href': 'https://api.spotify.com/v1/tracks/71NvO4cZEmDcVg0s1ryrfg',
#    'id': '71NvO4cZEmDcVg0s1ryrfg',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Rivalry',
#    'popularity': 50,
#    'preview_url': None,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:71NvO4cZEmDcVg0s1ryrfg'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#       'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#       'id': '6urzdpGY5yUimWZsgJUoTb',
#       'name': 'Airbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3exqV2MhKWetLhgfc7RPBO'},
#     'href': 'https://api.spotify.com/v1/albums/3exqV2MhKWetLhgfc7RPBO',
#     'id': '3exqV2MhKWetLhgfc7RPBO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730b08421d532524e82068010f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020b08421d532524e82068010f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510b08421d532524e82068010f',
#       'width': 64}],
#     'name': 'Boneshaker',
#     'release_date': '2019-10-25',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:3exqV2MhKWetLhgfc7RPBO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#      'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#      'id': '6urzdpGY5yUimWZsgJUoTb',
#      'name': 'Airbourne',
#      'type': 'artist',
#      'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#    'disc_number': 1,
#    'duration_ms': 210103,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71903529'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/272RnVOeeuc8xE6jCpbRAe'},
#    'href': 'https://api.spotify.com/v1/tracks/272RnVOeeuc8xE6jCpbRAe',
#    'id': '272RnVOeeuc8xE6jCpbRAe',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Boneshaker',
#    'popularity': 50,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:272RnVOeeuc8xE6jCpbRAe'}]}

# %%
print(type(top_tracks))
top_tracks.keys()
# Out:
# <class 'dict'>
# dict_keys(['tracks'])

# %%
df_top_tracks = pd.DataFrame(top_tracks['tracks'], columns = ['name', 'id', 'artists'])
df_top_tracks
# Out:
#                             name                      id  \
# 0                   Runnin' Wild  71fSn6OIF7HnCbgCzOBqpj
# 1  Too Much, Too Young, Too Fast  2LQbBzrXkgQHnCDUmHjReH
# 2            Breakin' Outta Hell  3HFqO1Khvk1pdmhjz3tXsk
# 3               Back In the Game  2XjeZEdPK7Qo66Z7ONp854
# 4                     Live It Up  0sa1kd1ZDMHopmdY66GcOQ
# 5      It's All For Rock N' Roll  6seQdTp9Vi0BE3z4DdJSAE
# 6                   Heartbreaker  1R8T9Hnsz0M01pheJIi5qT
# 7                Backseat Boogie  4Uj8nBnk0tKpu2qIeLqUvZ
# 8                        Rivalry  71NvO4cZEmDcVg0s1ryrfg
# 9                     Boneshaker  272RnVOeeuc8xE6jCpbRAe
#
#                                              artists
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
# 5  [{'external_urls': {'spotify': 'https://open.s...
# 6  [{'external_urls': {'spotify': 'https://open.s...
# 7  [{'external_urls': {'spotify': 'https://open.s...
# 8  [{'external_urls': {'spotify': 'https://open.s...
# 9  [{'external_urls': {'spotify': 'https://open.s...

# %%
df_top_tracks['artists'][0][0]['name']
# Out:
# 'Airbourne'

# %%
def art_names(x):
    return df_top_tracks['artists'][0][0]['name']

# %%
top_top = []
for i in id_related_artists:
    url_id_top = base_url + resource + '/'+ id_relart + "/top-tracks" + market
    df_top_tracks = pd.DataFrame(top_tracks['tracks'])
    df_top_tracks = df_top_tracks[['name', 'id','artists']]
    df_top_tracks['artists'] = df_top_tracks['artists'].apply(art_names)
    top_top.append(df_top_tracks)
    df_top_tracks = pd.concat(top_top)
df_top_tracks.head(50)
# Out:
#                             name                      id    artists
# 0                   Runnin' Wild  71fSn6OIF7HnCbgCzOBqpj  Airbourne
# 1  Too Much, Too Young, Too Fast  2LQbBzrXkgQHnCDUmHjReH  Airbourne
# 2            Breakin' Outta Hell  3HFqO1Khvk1pdmhjz3tXsk  Airbourne
# 3               Back In the Game  2XjeZEdPK7Qo66Z7ONp854  Airbourne
# 4                     Live It Up  0sa1kd1ZDMHopmdY66GcOQ  Airbourne
# 5      It's All For Rock N' Roll  6seQdTp9Vi0BE3z4DdJSAE  Airbourne
# 6                   Heartbreaker  1R8T9Hnsz0M01pheJIi5qT  Airbourne
# 7                Backseat Boogie  4Uj8nBnk0tKpu2qIeLqUvZ  Airbourne
# 8                        Rivalry  71NvO4cZEmDcVg0s1ryrfg  Airbourne
# 9                     Boneshaker  272RnVOeeuc8xE6jCpbRAe  Airbourne
# 0                   Runnin' Wild  71fSn6OIF7HnCbgCzOBqpj  Airbourne
# 1  Too Much, Too Young, Too Fast  2LQbBzrXkgQHnCDUmHjReH  Airbourne
# 2            Breakin' Outta Hell  3HFqO1Khvk1pdmhjz3tXsk  Airbourne
# 3               Back In the Game  2XjeZEdPK7Qo66Z7ONp854  Airbourne
# 4                     Live It Up  0sa1kd1ZDMHopmdY66GcOQ  Airbourne
# 5      It's All For Rock N' Roll  6seQdTp9Vi0BE3z4DdJSAE  Airbourne
# 6                   Heartbreaker  1R8T9Hnsz0M01pheJIi5qT  Airbourne
# 7                Backseat Boogie  4Uj8nBnk0tKpu2qIeLqUvZ  Airbourne
# 8                        Rivalry  71NvO4cZEmDcVg0s1ryrfg  Airbourne
# 9                     Boneshaker  272RnVOeeuc8xE6jCpbRAe  Airbourne
# 0                   Runnin' Wild  71fSn6OIF7HnCbgCzOBqpj  Airbourne
# 1  Too Much, Too Young, Too Fast  2LQbBzrXkgQHnCDUmHjReH  Airbourne
# 2            Breakin' Outta Hell  3HFqO1Khvk1pdmhjz3tXsk  Airbourne
# 3               Back In the Game  2XjeZEdPK7Qo66Z7ONp854  Airbourne
# 4                     Live It Up  0sa1kd1ZDMHopmdY66GcOQ  Airbourne
# 5      It's All For Rock N' Roll  6seQdTp9Vi0BE3z4DdJSAE  Airbourne
# 6                   Heartbreaker  1R8T9Hnsz0M01pheJIi5qT  Airbourne
# 7                Backseat Boogie  4Uj8nBnk0tKpu2qIeLqUvZ  Airbourne
# 8                        Rivalry  71NvO4cZEmDcVg0s1ryrfg  Airbourne
# 9                     Boneshaker  272RnVOeeuc8xE6jCpbRAe  Airbourne
# 0                   Runnin' Wild  71fSn6OIF7HnCbgCzOBqpj  Airbourne
# 1  Too Much, Too Young, Too Fast  2LQbBzrXkgQHnCDUmHjReH  Airbourne
# 2            Breakin' Outta Hell  3HFqO1Khvk1pdmhjz3tXsk  Airbourne
# 3               Back In the Game  2XjeZEdPK7Qo66Z7ONp854  Airbourne
# 4                     Live It Up  0sa1kd1ZDMHopmdY66GcOQ  Airbourne
# 5      It's All For Rock N' Roll  6seQdTp9Vi0BE3z4DdJSAE  Airbourne
# 6                   Heartbreaker  1R8T9Hnsz0M01pheJIi5qT  Airbourne
# 7                Backseat Boogie  4Uj8nBnk0tKpu2qIeLqUvZ  Airbourne
# 8                        Rivalry  71NvO4cZEmDcVg0s1ryrfg  Airbourne
# 9                     Boneshaker  272RnVOeeuc8xE6jCpbRAe  Airbourne
# 0                   Runnin' Wild  71fSn6OIF7HnCbgCzOBqpj  Airbourne
# 1  Too Much, Too Young, Too Fast  2LQbBzrXkgQHnCDUmHjReH  Airbourne
# 2            Breakin' Outta Hell  3HFqO1Khvk1pdmhjz3tXsk  Airbourne
# 3               Back In the Game  2XjeZEdPK7Qo66Z7ONp854  Airbourne
# 4                     Live It Up  0sa1kd1ZDMHopmdY66GcOQ  Airbourne
# 5      It's All For Rock N' Roll  6seQdTp9Vi0BE3z4DdJSAE  Airbourne
# 6                   Heartbreaker  1R8T9Hnsz0M01pheJIi5qT  Airbourne
# 7                Backseat Boogie  4Uj8nBnk0tKpu2qIeLqUvZ  Airbourne
# 8                        Rivalry  71NvO4cZEmDcVg0s1ryrfg  Airbourne
# 9                     Boneshaker  272RnVOeeuc8xE6jCpbRAe  Airbourne

# %% [markdown]
# base_url = 'https://api.spotify.com/v1'
# resource = '/artists'
# parameters = '/711MCceyCBcFnzjGY4Q7Un'
# header = {'Authorization': 'Bearer {token}'.format(token=access_token)}
# header
#
# artist = requests.get(base_url + resource + parameters, headers = header).json()
# artist

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)
